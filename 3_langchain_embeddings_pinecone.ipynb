# %% [markdown]
# #### Splitting and Embedding Text Using LangChain

# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

with open('files/churchill_speech.txt') as f:
    churchill_speech = f.read()

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20,
    length_function=len
)

# %%
chunks = text_splitter.create_documents([churchill_speech])
print(chunks[0])
# Out:
# page_content='Winston Churchill Speech - We Shall Fight on the Beaches\nWe Shall Fight on the Beaches\nJune 4, 1940'

# %%
print(chunks[1].page_content)
# Out:
# June 4, 1940
# House of Commons

# %%
print(f'Length of chunks: {len(chunks)}')
# Out:
# Length of chunks: 300

# %% [markdown]
# #### Embedding Cost

# %%
def print_embedding_cost(texts):
    import tiktoken
    enc = tiktoken.encoding_for_model('text-embedding-ada-002')
    total_token = sum([len(enc.encode(page.page_content)) for page in texts])
    print(f'Total Token: {total_token}')
    print(f'Embedding Cost in USD: {total_token / 1000 * 0.0004:.6f}')

print_embedding_cost(chunks)
# Out:
# Total Token: 4820
# Embedding Cost in USD: 0.001928

# %%
from langchain.embeddings import OpenAIEmbeddings
embedding = OpenAIEmbeddings()

# %%
vector = embedding.embed_query(chunks[0].page_content)
print(vector)
# Out:
# [-0.04454859252972275, -0.03779107625713776, -0.002879912206270699, -0.008045266214119192, 0.015746282084248255, 0.022516546299967938, -0.02843255862727964, -0.009734645282265439, 0.0010447052554574756, 0.007229264674373191, 0.007854016333454415, 0.032742067486658956, 0.007420515020699245, -0.011723648511527381, 0.006314450277188572, -0.005351823642668397, 0.013234526573466103, -0.0025308802194518626, 0.013502277151454833, -0.011003272377775045, -0.008140891620112858, -0.02685155477090687, 0.029554560162353798, -0.0037612576647914073, -0.01436927884564262, -0.01841103805835576, 0.010837522108669883, -0.01865328809346232, 0.0030615999654312587, -0.014356529039862813, 0.007114514559709814, -0.008568017564316847, -0.016536783081112085, 0.005144635573456307, -0.018296287943692383, -0.023880797870148653, -0.022465545214203596, -0.008727392930532107, 0.0226057968030717, -0.012743650669040521, 0.013629778003220573, 0.00470475982347251, 0.00875289254209172, 0.0029516310279353096, -0.027922557082861794, 0.022299795876420992, 0.020578542293825226, -0.009887644814268239, -0.0159630325077952, 0.044242589740426934, 0.013808278078105543, 0.019201539055219593, -0.018678787705021935, -0.03781657586869738, -0.016881035287747325, 0.009039768760072718, -0.021802544137782952, 0.01960954029075387, -0.006193325259635291, -0.02204479417288951, -0.004379633722490812, -0.009760144893825054, -0.011411273613309323, -0.011481398476420818, -0.001418440340220647, -0.009894019717158142, -0.03406806963950025, 0.033889568633292726, -0.0011538773300921869, 0.011092522880878806, 0.032104566021797926, 0.027310555229560378, 0.004408321716817934, 0.011551523339532315, 0.014688029578073136, -0.011328398013095464, -0.019737040211197054, -0.01702128501397032, 0.004083195615836237, 0.011902149517734904, 0.018538537978798945, -0.017123285322853888, 0.0010311583539857915, 0.010576146433571056, 0.030013560621007306, 0.005335885919782361, 0.008453267449653471, 0.02664755415313973, 0.0028384746389944087, -0.022937297341282022, -0.010136270683587259, -0.00020320353662717732, 0.005135072753460174, 0.004902385072688468, -0.012673525805929025, 0.02096104205515478, -0.015644281775364685, 0.02654555384425616, 0.017199784157532733, -0.02470955014699702, 0.027132056085997964, 0.005409198700000086, -0.0150705312020478, -0.007713765675908869, -0.011290147664433488, -0.0012789870111976156, -0.014280029273861412, -0.0075416405039138035, -0.006508888074959578, -0.00670013888694691, -0.014688029578073136, 0.010945897320443355, 0.014165279159198036, -0.03855607950508709, 0.0007387046198450654, -0.0427125869698185, -0.004319071213714172, -0.013036901789911423, 0.014356529039862813, -0.03564907163322791, 0.010620771685122937, -0.0014630654753572086, 0.017646036673051542, -0.005221135805118984, 0.0033532568949184065, 0.016001281925134624, -0.021075792169818156, -0.014917530738722446, 0.01985179032586043, 0.015108780619387223, 0.03554707318698946, 0.027973556305981022, 0.030396062244981967, -0.03850508028196786, -0.02295004714706183, 0.027132056085997964, -0.01781178601083415, 0.007656390618577181, -0.011392147973317057, -5.1547957641119845e-05, 0.012310149821946628, 0.04006058266413591, -0.014790029886956706, -0.013935777998548726, -0.00020659026199509837, 0.023217796793728006, 0.02889155908593315, 0.008491516866992893, 0.0032114127444810227, -0.009887644814268239, 0.009320269143841257, -0.00670013888694691, 0.0204000412876177, -0.000938720690475376, 0.02300104637018106, 0.01337477723101165, -0.013553277305896618, 0.0265965549300205, -0.013170776613244511, -0.0006948764057774014, 0.040443084288110574, 0.03024306085033406, 0.030523562165425153, 0.010958647126223164, 0.0418200856640711, 0.013234526573466103, 0.0240975482936956, 0.008663642970310513, -0.010958647126223164, 0.025831553544716283, 0.012240024958835131, 0.010767397245558388, -0.007930516099455815, 0.002894255970603621, -0.003091881219819579, 0.03437406870350585, 0.02254204591152755, -0.002878318480548223, -0.002919756047824514, -0 ...

# %% [markdown]
# #### Inserting the Embeddings into a Pinecone Index

# %%
import os
import pinecone
from langchain.vectorstores import Pinecone

pinecone.init(api_key=os.environ.get('PINECONE_API_KEY'), environment=os.environ.get('PINECONE_ENV'))

# %%
# deleting all indexex

indexes = pinecone.list_indexes()

for i in indexes:
    print('Deleting all indexes ... ', end='')
    pinecone.delete_index(i)
    print('Done')
# Out:
# Deleting all indexes ... Done

# %%
index_name = 'churchill-speech'
if index_name not in pinecone.list_indexes():
    print('Creating indexx {index_name} ...')
    pinecone.create_index(index_name, dimension=1536, metric='cosine')
    print('Done!')
# Out:
# Creating indexx {index_name} ...
# Done!

# %%
vector_store = Pinecone.from_documents(chunks, embedding, index_name=index_name)

# %% [markdown]
# #### Asking Questions (Similarity Search)

# %%
query = 'Where should we fight?'
result = vector_store.similarity_search(query)
print(result)
# Out:
# [Document(page_content='shall fight on the beaches, we shall fight on the landing grounds, we shall fight in the fields and'), Document(page_content='front, now on that, fighting'), Document(page_content='end, we shall fight in France, we shall fight on the seas and oceans, we shall fight with growing'), Document(page_content='Winston Churchill Speech - We Shall Fight on the Beaches\nWe Shall Fight on the Beaches\nJune 4, 1940')]

# %%
for r in result:
    print(r.page_content)
    print('-' * 50)
# Out:
# shall fight on the beaches, we shall fight on the landing grounds, we shall fight in the fields and
# --------------------------------------------------
# front, now on that, fighting
# --------------------------------------------------
# end, we shall fight in France, we shall fight on the seas and oceans, we shall fight with growing
# --------------------------------------------------
# Winston Churchill Speech - We Shall Fight on the Beaches
# We Shall Fight on the Beaches
# June 4, 1940
# --------------------------------------------------

# %%
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=1)

retriever = vector_store.as_retriever(search_type='similarity', search_kwargs={'k': 3})

chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)

# %%
# query = 'Where should we fight?'
# query = 'Who was the king of Belgium at that time?'
query = 'What about the French Armies?'
answer = chain.run(query)
print(answer)
# Out:
# The French Armies were also involved in the fighting. They held certain positions along the front lines and were tasked with advancing across the Somme in large numbers to seize territory.
